# %% [markdown]
# # 2.9.1 Математические вычисления и числа, типы коллекций

# %% [markdown]
# ## Задание 1

# %% [markdown]
# **Условие:**
#
# Напишите функцию, которая случайно переставляет буквы во введенном слове.

# %% [markdown]
# **Решение:**

# %%
import random

def shuffle_word(word):
    # Преобразуем строку в список символов
    letters = list(word)
    # Перемешиваем буквы
    random.shuffle(letters)
    # Соединяем перемешанные буквы в одно слово
    shuffled_word = ''.join(letters)
    return shuffled_word

# Пример использования функции
word = input("Введите слово: ")
shuffled_word = shuffle_word(word)
print("Переставленное слово:", shuffled_word)
# Out:
# Введите слово: привет
# Переставленное слово: твпеир

# %% [markdown]
# ## Задание 2

# %% [markdown]
# **Условие:**
# Используя методы модуля ```math```, найти значения $e^{\pi}$ и $\pi^{e}$. В случае, если первое выражение больше,то в ответе укажите 1, иначе - 0.
#
# **Формат ответа:**
# Число (например, ```1```)

# %% [markdown]
# **Решение:**

# %%
import math

# Находим значения выражений
exp1 = math.exp(math.pi)
exp2 = math.pi * math.e

# Сравниваем значения и возвращаем результат
if exp1 > exp2:
    result = 1
else:
    result = 0

print(result)
# Out:
# 1
