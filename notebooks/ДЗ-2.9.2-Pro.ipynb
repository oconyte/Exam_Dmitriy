# %% [markdown]
# # 2.9.2 Работа с аргументами командной строки, время и дата

# %% [markdown]
# ## Задание 1

# %% [markdown]
# **Условие:**
# Методами библиотеки ```datetime``` найти количество високосных годов с начала Unix эпохи и по настоящий момент.
#
# **Формат ответа:**
# Число (например, ```2```)

# %% [markdown]
# **Решение:**

# %%
import datetime

# Дата начала Unix эпохи
start_date = datetime.datetime(1970, 1, 1)

# Настоящая дата
end_date = datetime.datetime.now()

# Инициализируем переменную для подсчета високосных годов
leap_years = 0

# Перебираем года с начала Unix эпохи до настоящего момента
for year in range(start_date.year, end_date.year + 1):
    # Проверяем, является ли год високосным
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
        leap_years += 1

print(leap_years)
# Out:
# 14

# %% [markdown]
# ## Задание 2

# %% [markdown]
# **Условие:**
# Методами библиотеки ```datetime``` найдите название дня недели, в который вы родились. Посчитайте также количество секунд, которые вы провели на этой планете до ```01.01.2020```.
#
# **Формат ответа:** кортеж (например, ```('monday',123213875)```)

# %% [markdown]
# **Решение:**

# %%
import datetime

# Введите вашу дату рождения в формате (год, месяц, день)
birthday = datetime.date(1990, 5, 15)

# Найдите день недели для вашей даты рождения
weekday = birthday.strftime("%A").lower()

# Найдите количество секунд, прошедших с вашего дня рождения до 01.01.2020
time_since_birth = (datetime.datetime(2020, 1, 1) - datetime.datetime.combine(birthday, datetime.time.min)).total_seconds()

result = (weekday, int(time_since_birth))
print(result)
# Out:
# ('tuesday', 935107200)
