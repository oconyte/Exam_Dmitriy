# %% [markdown]
# # 3.2.5 Файловый ввод-вывод массивов

# %% [markdown]
# ## Задание 1

# %% [markdown]
# **Условие:**
# Создайте массив ```ndarray``` размера ```(15,15)``` элементов, взятых из стандартного нормального распределения. Запишите данный массив в файл в бинарном виде. Считайте массив из файла, с использованием целочисленного типа данных. Найдите абсолютное значение разности сумм элементов исходного массива и считанного из файла. Используйте ```np.random.seed(1000)``` перед генерацией массива для воспроизводимости результатов.
#
# **Формат ответа:**
# Число (например, ```102.4```)

# %% [markdown]
# **Решение:**

# %%
import numpy as np

# Устанавливаем seed для воспроизводимости результатов
np.random.seed(1000)

# Создаем массив размера (15,15) из стандартного нормального распределения
array = np.random.randn(15, 15)

# Записываем массив в файл в бинарном виде
with open("array.bin", "wb") as f:
    array.tofile(f)

# Считываем массив из файла, используя целочисленный тип данных (int)
array_from_file = np.fromfile("array.bin", dtype=int).reshape(15, 15)

# Находим абсолютное значение разности сумм элементов исходного массива и считанного из файла
absolute_difference = np.abs(np.sum(array) - np.sum(array_from_file))

absolute_difference
# Out:
# 2.798872677154546e+18

# %% [markdown]
# ## Задание 2

# %% [markdown]
# **Условие:**
# Создайте массив ```ndarray``` размера ```100```, взятых из стандартного нормального распределения. Запишите данный массив в файл в бинарном виде с использованием функций ```np.save()``` и ```np.savez_compressed()```. Найдите абсолютное значение разности байтовых размеров полученных файлов. Используйте ```np.random.seed(1000)``` перед генерацией массива для воспроизводимости результатов.
#
# **Формат ответа:**
# Число (например, ```45```)

# %% [markdown]
# **Решение:**

# %%
import numpy as np
import os

# Устанавливаем seed для воспроизводимости результатов
np.random.seed(1000)

# Создаем массив размера 100 из стандартного нормального распределения
array = np.random.randn(100)

# Записываем массив в файл с использованием np.save()
np.save("array.npy", array)

# Записываем массив в файл с использованием np.savez_compressed()
np.savez_compressed("array_compressed.npz", array=array)

# Находим размеры файлов
size_npy = os.path.getsize("array.npy")
size_npz = os.path.getsize("array_compressed.npz")

# Находим абсолютное значение разности байтовых размеров полученных файлов
absolute_difference = np.abs(size_npy - size_npz)

absolute_difference
# Out:
# 114
